# %%
#!pipenv install mplfinance
#!pipenv

# %%
import numpy as np
import pandas as pd
import mplfinance as mpf
import matplotlib.pyplot as plt
from datetime import datetime as dt
import os
import warnings
#warnings.simplefilter('ignore')

# %%
#file_list = ['-20', '-19_0', '-19_1', '-18_0', '-18_1', '-17_0', '-17_1', '-16_0', '-16_1', '-15_0', '-15_1', '-14_0', '-14_1', '-13_0', '-13_1', '-12_0', '-12_1', '-11_0', '-11_1', '-10_0', '-10_1', '-9_0', '-9_1', '-8_0', '-8_1', '-7_0', '-7_1', '-6_0', '-6_1', '-5_0', '-5_1', '-4_0', '-4_1', '-3_0', '-3_1', '-2_0', '-2_1', '-1_0', '-1_1','-0_0','-0_1','0','0_0', '0_1','1_0', '1_1', '2_0', '2_1', '3_0', '3_1', '4_0', '4_1', '5_0', '5_1', '6_0', '6_1', '7_0', '7_1', '8_0', '8_1', '9_0', '9_1', '10_0', '10_1', '11_0', '11_1', '12_0', '12_1', '13_0', '13_1', '14_0', '14_1', '15_0', '15_1', '16_0', '16_1', '17_0', '17_1', '18_0', '18_1', '19_0', '19_1', '20']
file_list = ['_-1','0','1_']
for file_name in file_list:
    new_dir_path = '../data/sony/test/' + file_name
    new_dir_path = '../data/sony/train/' + file_name
    os.makedirs(new_dir_path, exist_ok=True)

# %%
df = pd.read_csv('../data/sony/sony_data.csv', index_col=0, parse_dates=True)
df.columns = ['Open', 'High', 'Low', 'Close', 'Volume','per_100']
df_row = pd.read_csv('../data/sony/sony_data.csv')
print(df)
# Out:
#               Open    High     Low   Close  Volume  per_100
# data
# 2020-12-01  9915.0  9925.0  9768.0  9800.0  2595.1     0.99
# 2020-11-30  9764.0  9800.0  9704.0  9704.0  6713.2    -1.10
# 2020-11-27  9777.0  9829.0  9762.0  9812.0  4199.7     0.59
# 2020-11-26  9747.0  9799.0  9734.0  9754.0  2158.8    -0.57
# 2020-11-25  9780.0  9826.0  9710.0  9810.0  5154.8     3.37
# ...            ...     ...     ...     ...     ...      ...
# 2001-10-05  4320.0  4440.0  4310.0  4380.0  3138.0     3.06
# 2001-10-04  4120.0  4250.0  4100.0  4250.0  3013.1     6.78
# 2001-10-03  4010.0  4030.0  3960.0  3980.0  4487.8    -1.73
# 2001-10-02  4010.0  4050.0  4010.0  4050.0  3689.3    -1.22
# 2001-10-01  4040.0  4160.0  4040.0  4100.0  3622.8      NaN
#
# [4679 rows x 6 columns]

# %%
#mpf.plot(df[0:30], type='candle', figratio=(12,4),savefig='../data/apple_data/train/0/candlestick_mpf_candle.png')

# %%
close = np.array(df_row["close"])
date = np.array(df_row["data"])
close
# Out:
# array([9800., 9704., 9812., ..., 3980., 4050., 4100.])

# %%
close_first = np.delete(close,-1)
close_second = np.delete(close,0)
#print(len(close_first),len(close_second))
close_per_100 = (close_first - close_second) / close_second * 100
#close_per_10000 = (close_first - close_second) / close_second * 10000
close_per_sort = np.sort(close_per_100)

# %%
plt.plot(close_per_sort)

# %% [markdown]
# ### thetaの作成

# %%
theta_list = [-1]
while theta_list[-1] != 1:
    theta_list.append(theta_list[-1] + 2)

print(len(theta_list),theta_list)
print(len(file_list),file_list)
# Out:
# 2 [-1, 1]
# 3 ['_-1', '0', '1_']

# %% [markdown]
# ### データわけの確認

# %%
count_data = [0,0,0]
for ele_data in df.values:
    if ele_data[5] > 0:
        count_data[0] += 1
    elif ele_data[5] == 0:
        count_data[1] += 1
    elif ele_data[5] < 0:
        count_data[2] += 1
print(count_data)
# Out:
# [2274, 115, 2289]

# %% [markdown]
# ### thetaの幅でデータポイント作成 データ４つ以上

# %%
keep = []
point_data = [] 
point = False
theta_ = -200
theta_list.append(200)

for theta in theta_list:
    for ele_data in df.values:
        if theta > ele_data[5] and ele_data[5] > theta_:
            keep.append(list(ele_data[:5]))
    print(theta,">",theta_)
    theta_ = theta
    point_data.append(keep)
    keep = []
# Out:
# -1 > -200
# 1 > -1
# 200 > 1

# %% [markdown]
# ### thetaの幅でデータポイント作成 データ３つ以下

# %%
keep = []
point_data = [] 
point = False
theta_list = [0]
theta_ = -200
theta_list.append(200)

for theta in theta_list:
    for ele_data in df.values:
        if theta > ele_data[5] and ele_data[5] > theta_:
            keep.append(list(ele_data[:5]))
    print(theta,">",theta_)
    theta_ = theta
    point_data.append(keep)
    keep = []
# Out:
# 0 > -200
# 200 > 0

# %% [markdown]
# ### 0でデータポイント作成

# %%
point_data_0 = [] 
point = False

for ele_data in df.values:
    if ele_data[5] == 0:
        point_data_0.append(list(ele_data[:5]))
print(len(point_data_0))
# Out:
# 115

# %% [markdown]
# ### データポイントの合成

# %%
point_data.append(point_data_0)
print(len(point_data))
for data in point_data:
    print(len(data))
# Out:
# 3
# 2289
# 2274
# 115

# %% [markdown]
# # 0

# %%
count = 0
data_0 = []
for point in point_data[0]:
    check = False
    keep = []
    for ele_data in df.values:
        if check == True:
            keep.append(ele_data[:5])
            if len(keep) == 7:
                data_0.append(keep)
                check = False
        if point == list(ele_data[:5]):
            count += 1
            check = True
print(count)
# Out:
# 2289

# %%
print(len(data_0))
for i in data_0:
    pass
    #print(len(i))
# Out:
# 2286

# %% [markdown]
# # 1

# %%
count = 0
data_1 = []
for point in point_data[1]:
    check = False
    keep = []
    for ele_data in df.values:
        if check == True:
            keep.append(ele_data[:5])
            if len(keep) == 7:
                data_1.append(keep)
                check = False
        if point == list(ele_data[:5]):
            count += 1
            check = True
print(count)
# Out:
# 2274

# %%
print(len(data_1))
for i in data_1:
    pass
    #print(len(i))
# Out:
# 2271

# %% [markdown]
# # 2

# %%
count = 0
data_2 = []
for point in point_data[2]:
    check = False
    keep = []
    for ele_data in df.values:
        if check == True:
            keep.append(ele_data[:5])
            if len(keep) == 7:
                data_2.append(keep)
                check = False
        if point == list(ele_data[:5]):
            count += 1
            check = True
print(count)
# Out:
# 115

# %%
print(len(data_2))
for i in data_2:
    pass
    #print(len(i))
# Out:
# 115

# %% [markdown]
# # 3

# %%
count = 0
data_3 = []
for point in point_data[3]:
    check = False
    keep = []
    for ele_data in df.values:
        if check == True:
            keep.append(ele_data[:5])
            if len(keep) == 7:
                data_3.append(keep)
                check = False
        if point == list(ele_data[:5]):
            count += 1
            check = True
print(count)
# Out:
# 1138

# %%
print(len(data_3))
count = 0
for i in data_3:
    #print(len(i))
    if 7 != len(i):
        print("7error")
        print(count)
    if count == 1:
        print(i)
    count += 1
    for t in i:
        if 5 != len(t):
            print("5error")
# Out:
# 1135
# [array([196. , 201. , 196. , 200. ,  63.1]), array([193. , 193. , 190. , 191. ,  29.6]), array([188. , 195. , 187. , 193. , 105.4]), array([185. , 189. , 185. , 188. ,  85.3]), array([188. , 189. , 186. , 187. ,  70.5]), array([196. , 198. , 196. , 198. ,  31.2]), array([200. , 201. , 196. , 198. ,  40.8])]
# 7error
# 529

# %% [markdown]
# # 4

# %%
count = 0
data_4 = []
for point in point_data[4]:
    check = False
    keep = []
    for ele_data in df.values:
        if check == True:
            keep.append(ele_data[:5])
            if len(keep) == 7:
                data_4.append(keep)
                check = False
        if point == list(ele_data[:5]):
            count += 1
            check = True
print(count)
# Out:
# 335

# %%
print(len(data_4))
for i in data_4:
    pass
    #print(len(i))
# Out:
# 335

# %% [markdown]
# # 実行関数

# %%
def list_to_df(data):
    try:
        df = pd.DataFrame(data,index=[dt(2000,1,1), dt(2000,1,2),dt(2000,1,3), dt(2000,1,4), dt(2000,1,5), dt(2000,1,6), dt(2000,1,7)],columns=['Open', 'High', 'Low', 'Close', 'Volume'])
        return(df)
    except:
        pass

# %%
#mpf.plot(data,type='candle', figratio=(12,4),savefig=pass_code + file_list[41] +"/"+ str(file_name) + ".jpg")
def data_to_dataset(data,path_train,path_val):
    file_name_train = 0
    file_name_val = 0
    count = 0
    leng = int(len(data) * (4/5))
    for ele_data in data:
        if count <= leng:
            df_data = list_to_df(ele_data)
            try:
                mpf.plot(df_data,type='candle', figratio=(12,4),savefig=str(path_train) +"/"+ str(file_name_train) + ".jpg")
            except:
                pass
            file_name_train += 1
        else :
            df_data = list_to_df(ele_data)
            try:
                mpf.plot(df_data,type='candle', figratio=(12,4),savefig=str(path_val) +"/"+ str(file_name_val) + ".jpg")
            except:
                pass
            file_name_val += 1
        count += 1
    return leng

# %%
#point_data.append(point_data_0)
print(len(point_data))
for data in point_data:
    print(len(data))
# Out:
# 3
# 2289
# 2274
# 115

# %% [markdown]
# ## 変更必要

# %%
data_to_dataset(data_0,"../data/sony/train/_-1","../data/sony/test/_-1")
# Out:
# 1828

# %%
data_to_dataset(data_1,"../data/sony/train/1_","../data/sony/test/1_")
# Out:
# 1816

# %%
data_to_dataset(data_2,"../data/sony/train/0","../data/sony/test/0")
# Out:
# 92

# %%
data_to_dataset(data_3,"../data/apple_data/train/1_","../data/apple_data/test/1_")
# Out:
# 908

# %%
data_to_dataset(data_4,"../data/apple_data/train/0","../data/apple_data/test/0")
# Out:
# 268
